# %% [markdown]
# Estadisticas de los jugadores e implementacion de la funcion de devuelve una estructura de datos asociados a cada jugador o jugadora

# %%
import hockey
names = """Agustin, Yanina, Andrés, Ariadna, Bautista, CAROLINA,
CESAR, David, Diego, Dolores, DYLAN, ELIANA, Emanuel, Fabián, Noelia,
Francsica', FEDERICO, Fernanda, GONZALO, Nancy """
goals = [0, 10, 4, 0, 5, 14, 0, 0, 7, 2, 1, 1, 1, 5, 6, 1, 1, 2, 0,11]
goals_avoided = [0, 2, 0, 0, 5, 2, 0, 0, 1, 2, 0, 5, 5, 0, 1, 0, 2,3, 0, 0]
assists = [0, 5, 1, 0, 5, 2, 0, 0, 1, 2, 1, 5, 5, 0, 1, 0, 2, 3, 1,0]

players=hockey.generar_estructura(names,goals,goals_avoided,assists)

# %% [markdown]
# Funcion que devuelve el nombre del jugador con mas goles del equipo

# %%
goleador,max_goles=hockey.obtener_goleador(players)
print(goleador)
print(max_goles)
# Out:
# ['CAROLINA']
# 14
